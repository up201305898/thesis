# %%
cm = [[110,   0,   8,   1,   9,  22,   0,  12,   9,  32],
       [  3,  64,   4,   1,   1,   4,   2,   5,   0,   2],
       [ 19,   0,  98,  19,  12,   9,   0,   1,   7,  18],
       [ 10,   3,  12, 137,   9,   6,   1,   0,  14,   9],
       [ 13,   1,  15,   5, 114,   9,   1,  29,   7,  12],
       [ 38,   0,   7,   3,   2, 102,   0,  24,   8,   9],
       [  1,   1,   1,  33,   6,   0,   7,   2,   1,  20],
       [ 13,   2,   1,   0,  27,  10,   0, 145,   3,   7],
       [  9,   0,   7,   4,   0,  13,   1,   2, 129,   0],
       [ 38,   4,  28,   9,  20,  12,   0,  15,   5,  99]]

# %%
from matplotlib import pyplot as plt
import seaborn as sn
plt.figure(figsize = (10,7))
sn.heatmap(cm, annot=True)
plt.xlabel('Predicted')
plt.ylabel('Truth')
# Out:
# Text(69.0, 0.5, 'Truth')
